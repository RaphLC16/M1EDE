# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

data=pd.read_csv('dep_48_clean_num.csv')
df=data.copy()

# %%
df.columns
# Out:
# Index(['consommation_energie', 'classe_consommation_energie', 'estimation_ges',
#        'classe_estimation_ges', 'annee_construction', 'surface_habitable',
#        'nombre_niveaux', 'surface_baies_orientees_nord',
#        'surface_baies_orientees_est_ouest', 'surface_baies_orientees_sud',
#        'surface_planchers_hauts_deperditifs',
#        'surface_planchers_bas_deperditifs',
#        'surface_parois_verticales_opaques_deperditives', 'longitude',
#        'latitude', 'copropriete', 'location', 'neuf', 'vente', 'appartement',
#        'logements_collectifs', 'maison'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier


X = df.iloc[:, 5:]  # Prend les colonnes à partir de l'index 5
Y = (df.iloc[:, 1] + df.iloc[:, 3] >= 1).astype(int)  


model = DecisionTreeClassifier()
model.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5097108644859814, 0.9705882352941176, 'x[13] <= 0.5\ngini = 0.492\nsamples = 528\nvalue = [298, 230]'),
#  Text(0.17873831775700935, 0.9117647058823529, 'x[4] <= 4.255\ngini = 0.383\nsamples = 174\nvalue = [129, 45]'),
#  Text(0.34422459112149534, 0.9411764705882353, 'True  '),
#  Text(0.06775700934579439, 0.8529411764705882, 'x[7] <= 37.03\ngini = 0.492\nsamples = 89\nvalue = [50, 39]'),
#  Text(0.018691588785046728, 0.7941176470588235, 'x[5] <= 51.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.009345794392523364, 0.7352941176470589, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.028037383177570093, 0.7352941176470589, 'x[11] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.018691588785046728, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.037383177570093455, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11682242990654206, 0.7941176470588235, 'x[7] <= 55.59\ngini = 0.5\nsamples = 75\nvalue = [38, 37]'),
#  Text(0.06542056074766354, 0.7352941176470589, 'x[3] <= 6.2\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.056074766355140186, 0.6764705882352942, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.07476635514018691, 0.6764705882352942, 'x[8] <= 3.243\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06542056074766354, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08411214953271028, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16822429906542055, 0.7352941176470589, 'x[0] <= 62.8\ngini = 0.492\nsamples = 64\nvalue = [36, 28]'),
#  Text(0.12149532710280374, 0.6764705882352942, 'x[9] <= 44.349\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.102803738317757, 0.6176470588235294, 'x[7] <= 68.28\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09345794392523364, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11214953271028037, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14018691588785046, 0.6176470588235294, 'x[3] <= 7.8\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.1308411214953271, 0.5588235294117647, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.14953271028037382, 0.5588235294117647, 'x[6] <= 47.93\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14018691588785046, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1588785046728972, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21495327102803738, 0.6764705882352942, 'x[0] <= 93.8\ngini = 0.498\nsamples = 49\nvalue = [23, 26]'),
#  Text(0.19626168224299065, 0.6176470588235294, 'x[5] <= 79.42\ngini = 0.478\nsamples = 38\nvalue = [15, 23]'),
#  Text(0.18691588785046728, 0.5588235294117647, 'x[8] <= 3.247\ngini = 0.498\nsamples = 32\nvalue = [15, 17]'),
#  Text(0.17757009345794392, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19626168224299065, 0.5, 'x[7] <= 121.25\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.17289719626168223, 0.4411764705882353, 'x[5] <= 42.06\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.1542056074766355, 0.38235294117647056, 'x[0] <= 82.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14485981308411214, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.16355140186915887, 0.3235294117647059, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19158878504672897, 0.38235294117647056, 'x[9] <= 44.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.1822429906542056, 0.3235294117647059, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.20093457943925233, 0.3235294117647059, 'x[7] <= 92.63\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.19158878504672897, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2102803738317757, 0.2647058823529412, 'x[2] <= 2.685\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.20093457943925233, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.21962616822429906, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21962616822429906, 0.4411764705882353, 'x[0] <= 85.43\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.2102803738317757, 0.38235294117647056, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.22897196261682243, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.205607476635514, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.2336448598130841, 0.6176470588235294, 'x[9] <= 46.106\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.22429906542056074, 0.5588235294117647, 'x[2] <= 21.095\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.21495327102803738, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2336448598130841, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24299065420560748, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2897196261682243, 0.8529411764705882, 'x[2] <= 1.305\ngini = 0.131\nsamples = 85\nvalue = [79, 6]'),
#  Text(0.2803738317757009, 0.7941176470588235, 'x[0] <= 87.295\ngini = 0.355\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.27102803738317754, 0.7352941176470589, 'x[7] <= 123.675\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.2616822429906542, 0.6764705882352942, 'x[8] <= 3.416\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.2523364485981308, 0.6176470588235294, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.27102803738317754, 0.6176470588235294, 'x[4] <= 6.17\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.2616822429906542, 0.5588235294117647, 'x[3] <= 5.51\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2523364485981308, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.27102803738317754, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2803738317757009, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2803738317757009, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2897196261682243, 0.7352941176470589, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.29906542056074764, 0.7941176470588235, 'gini = 0.0\nsamples = 59\nvalue = [59, 0]'),
#  Text(0.8406834112149533, 0.9117647058823529, 'x[7] <= 188.27\ngini = 0.499\nsamples = 354\nvalue = [169, 185]'),
#  Text(0.6751971378504673, 0.9411764705882353, '  False'),
#  Text(0.7421144859813084, 0.8529411764705882, 'x[6] <= 101.155\ngini = 0.5\nsamples = 312\nvalue = [160, 152]'),
#  Text(0.6337616822429907, 0.7941176470588235, 'x[3] <= 6.305\ngini = 0.498\nsamples = 268\nvalue = [126, 142]'),
#  Text(0.5338785046728972, 0.7352941176470589, 'x[0] <= 129.25\ngini = 0.496\nsamples = 174\nvalue = [95.0, 79.0]'),
#  Text(0.5245327102803738, 0.6764705882352942, 'x[4] <= 6.655\ngini = 0.5\nsamples = 161\nvalue = [82, 79]'),
#  Text(0.4439252336448598, 0.6176470588235294, 'x[0] <= 87.5\ngini = 0.483\nsamples = 110\nvalue = [65, 45]'),
#  Text(0.34579439252336447, 0.5588235294117647, 'x[16] <= 0.5\ngini = 0.498\nsamples = 88\nvalue = [47, 41]'),
#  Text(0.2897196261682243, 0.5, 'x[8] <= 3.237\ngini = 0.432\nsamples = 38\nvalue = [26, 12]'),
#  Text(0.2803738317757009, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29906542056074764, 0.4411764705882353, 'x[5] <= 76.78\ngini = 0.401\nsamples = 36\nvalue = [26, 10]'),
#  Text(0.2897196261682243, 0.38235294117647056, 'x[5] <= 50.61\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.2803738317757009, 0.3235294117647059, 'x[2] <= 1.535\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(0.2523364485981308, 0.2647058823529412, 'x[0] <= 49.81\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.24299065420560748, 0.20588235294117646, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.2616822429906542, 0.20588235294117646, 'x[0] <= 65.94\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2523364485981308, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.27102803738317754, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.308411214953271, 0.2647058823529412, 'x[5] <= 46.765\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.29906542056074764, 0.20588235294117646, 'x[9] <= 44.794\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.2897196261682243, 0.14705882352941177, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.308411214953271, 0.14705882352941177, 'x[0] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.29906542056074764, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3177570093457944, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3177570093457944, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.29906542056074764, 0.3235294117647059, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.308411214953271, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40186915887850466, 0.5, 'x[0] <= 60.5\ngini = 0.487\nsamples = 50\nvalue = [21.0, 29.0]'),
#  Text(0.34579439252336447, 0.4411764705882353, 'x[6] <= 22.235\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(0.32710280373831774, 0.38235294117647056, 'x[7] <= 98.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3177570093457944, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3364485981308411, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3644859813084112, 0.38235294117647056, 'x[8] <= 3.615\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.35514018691588783, 0.3235294117647059, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.37383177570093457, 0.3235294117647059, 'x[3] <= 2.445\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3644859813084112, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.38317757009345793, 0.2647058823529412, 'x[3] <= 4.475\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.37383177570093457, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3925233644859813, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45794392523364486, 0.4411764705882353, 'x[0] <= 77.7\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.4392523364485981, 0.38235294117647056, 'x[8] <= 3.936\ngini = 0.434\nsamples = 22\nvalue = [15.0, 7.0]'),
#  Text(0.42990654205607476, 0.3235294117647059, 'x[3] <= 5.98\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.4205607476635514, 0.2647058823529412, 'x[6] <= 78.25\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.411214953271028, 0.20588235294117646, 'x[0] <= 65.03\ngini = 0.278\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.3925233644859813, 0.14705882352941177, 'x[8] <= 3.728\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.38317757009345793, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40186915887850466, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42990654205607476, 0.14705882352941177, 'x[3] <= 4.28\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.4205607476635514, 0.08823529411764706, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.4392523364485981, 0.08823529411764706, 'x[4] <= 5.015\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.42990654205607476, 0.029411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4485981308411215, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42990654205607476, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4392523364485981, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4485981308411215, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4766355140186916, 0.38235294117647056, 'x[0] <= 85.77\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.4672897196261682, 0.3235294117647059, 'x[5] <= 80.965\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.45794392523364486, 0.2647058823529412, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4766355140186916, 0.2647058823529412, 'x[0] <= 83.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4672897196261682, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.48598130841121495, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48598130841121495, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5420560747663551, 0.5588235294117647, 'x[7] <= 172.315\ngini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(0.5327102803738317, 0.5, 'x[8] <= 3.683\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.5046728971962616, 0.4411764705882353, 'x[9] <= 44.536\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.4953271028037383, 0.38235294117647056, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.514018691588785, 0.38235294117647056, 'x[6] <= 51.715\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5046728971962616, 0.3235294117647059, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5233644859813084, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5607476635514018, 0.4411764705882353, 'x[8] <= 3.743\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5514018691588785, 0.38235294117647056, 'x[9] <= 44.274\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5420560747663551, 0.3235294117647059, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5607476635514018, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5700934579439252, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5514018691588785, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6051401869158879, 0.6176470588235294, 'x[9] <= 44.258\ngini = 0.444\nsamples = 51\nvalue = [17, 34]'),
#  Text(0.5794392523364486, 0.5588235294117647, 'x[6] <= 38.455\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5700934579439252, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5887850467289719, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6308411214953271, 0.5588235294117647, 'x[7] <= 56.93\ngini = 0.391\nsamples = 45\nvalue = [12, 33]'),
#  Text(0.6074766355140186, 0.5, 'x[7] <= 13.75\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5981308411214953, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.616822429906542, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6542056074766355, 0.5, 'x[5] <= 87.955\ngini = 0.326\nsamples = 39\nvalue = [8.0, 31.0]'),
#  Text(0.6355140186915887, 0.4411764705882353, 'x[3] <= 5.325\ngini = 0.137\nsamples = 27\nvalue = [2, 25]'),
#  Text(0.6261682242990654, 0.38235294117647056, 'x[7] <= 143.4\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(0.616822429906542, 0.3235294117647059, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.6355140186915887, 0.3235294117647059, 'x[4] <= 13.705\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6261682242990654, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6448598130841121, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6448598130841121, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6728971962616822, 0.4411764705882353, 'x[3] <= 0.81\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.6635514018691588, 0.38235294117647056, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6822429906542056, 0.38235294117647056, 'x[2] <= 2.435\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.6728971962616822, 0.3235294117647059, 'x[1] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6635514018691588, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6822429906542056, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6915887850467289, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5432242990654206, 0.6764705882352942, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.7336448598130841, 0.7352941176470589, 'x[7] <= 100.215\ngini = 0.442\nsamples = 94\nvalue = [31.0, 63.0]'),
#  Text(0.7009345794392523, 0.6764705882352942, 'x[2] <= 0.125\ngini = 0.239\nsamples = 36\nvalue = [5, 31]'),
#  Text(0.6822429906542056, 0.6176470588235294, 'x[7] <= 93.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.6728971962616822, 0.5588235294117647, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.6915887850467289, 0.5588235294117647, 'x[5] <= 56.01\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6822429906542056, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7009345794392523, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.719626168224299, 0.6176470588235294, 'x[8] <= 3.28\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.7102803738317757, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7289719626168224, 0.5588235294117647, 'x[7] <= 70.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.719626168224299, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7383177570093458, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.7663551401869159, 0.6764705882352942, 'x[2] <= 5.13\ngini = 0.495\nsamples = 58\nvalue = [26, 32]'),
#  Text(0.7570093457943925, 0.6176470588235294, 'x[6] <= 43.5\ngini = 0.5\nsamples = 52\nvalue = [26, 26]'),
#  Text(0.7476635514018691, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7663551401869159, 0.5588235294117647, 'x[3] <= 18.76\ngini = 0.497\nsamples = 48\nvalue = [26, 22]'),
#  Text(0.7570093457943925, 0.5, 'x[3] <= 10.535\ngini = 0.483\nsamples = 44\nvalue = [26, 18]'),
#  Text(0.7289719626168224, 0.4411764705882353, 'x[9] <= 44.671\ngini = 0.493\nsamples = 25\nvalue = [11.0, 14.0]'),
#  Text(0.719626168224299, 0.38235294117647056, 'x[7] <= 110.0\ngini = 0.444\nsamples = 21\nvalue = [7, 14]'),
#  Text(0.7102803738317757, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7289719626168224, 0.3235294117647059, 'x[4] <= 17.995\ngini = 0.388\nsamples = 19\nvalue = [5, 14]'),
#  Text(0.719626168224299, 0.2647058823529412, 'x[4] <= 1.645\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.6915887850467289, 0.20588235294117646, 'x[8] <= 3.541\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6822429906542056, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7009345794392523, 0.14705882352941177, 'x[6] <= 74.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6915887850467289, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7102803738317757, 0.08823529411764706, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7476635514018691, 0.20588235294117646, 'x[9] <= 44.303\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.7383177570093458, 0.14705882352941177, 'x[5] <= 76.92\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7289719626168224, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7476635514018691, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7570093457943925, 0.14705882352941177, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7383177570093458, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7383177570093458, 0.38235294117647056, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7850467289719626, 0.4411764705882353, 'x[9] <= 44.23\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.7757009345794392, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.794392523364486, 0.38235294117647056, 'x[6] <= 97.3\ngini = 0.278\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.7850467289719626, 0.3235294117647059, 'x[3] <= 13.865\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.7757009345794392, 0.2647058823529412, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.794392523364486, 0.2647058823529412, 'x[7] <= 151.25\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.7850467289719626, 0.20588235294117646, 'x[4] <= 0.405\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7757009345794392, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.794392523364486, 0.14705882352941177, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8037383177570093, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8037383177570093, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7757009345794392, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7757009345794392, 0.6176470588235294, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8504672897196262, 0.7941176470588235, 'x[1] <= 2.5\ngini = 0.351\nsamples = 44\nvalue = [34, 10]'),
#  Text(0.8317757009345794, 0.7352941176470589, 'x[3] <= 26.36\ngini = 0.289\nsamples = 40\nvalue = [33, 7]'),
#  Text(0.822429906542056, 0.6764705882352942, 'x[0] <= 106.16\ngini = 0.26\nsamples = 39\nvalue = [33, 6]'),
#  Text(0.794392523364486, 0.6176470588235294, 'x[5] <= 102.765\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.7850467289719626, 0.5588235294117647, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8037383177570093, 0.5588235294117647, 'x[2] <= 4.595\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.794392523364486, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8130841121495327, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8504672897196262, 0.6176470588235294, 'x[8] <= 3.215\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.8411214953271028, 0.5588235294117647, 'x[7] <= 134.36\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.8317757009345794, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8504672897196262, 0.5, 'x[9] <= 44.435\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8411214953271028, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8598130841121495, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8598130841121495, 0.5588235294117647, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.8411214953271028, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8691588785046729, 0.7352941176470589, 'x[6] <= 188.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8598130841121495, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8785046728971962, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9392523364485982, 0.8529411764705882, 'x[9] <= 44.374\ngini = 0.337\nsamples = 42\nvalue = [9, 33]'),
#  Text(0.9158878504672897, 0.7941176470588235, 'x[7] <= 208.82\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.9065420560747663, 0.7352941176470589, 'x[2] <= 5.18\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.897196261682243, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9158878504672897, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9252336448598131, 0.7352941176470589, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9626168224299065, 0.7941176470588235, 'x[5] <= 143.095\ngini = 0.165\nsamples = 33\nvalue = [3, 30]'),
#  Text(0.9439252336448598, 0.7352941176470589, 'x[9] <= 44.389\ngini = 0.067\nsamples = 29\nvalue = [1, 28]'),
#  Text(0.9345794392523364, 0.6764705882352942, 'x[0] <= 157.07\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9252336448598131, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9439252336448598, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9532710280373832, 0.6764705882352942, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.9813084112149533, 0.7352941176470589, 'x[9] <= 44.481\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9719626168224299, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9906542056074766, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]
